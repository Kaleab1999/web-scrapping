# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaleab1999/web-scrapping/blob/main/Covid_data_from_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# twint is open source which used to scrape twitters data without limit like Twitter API.
# twint: Twitter Intelegence Tool

# %%
# !pip install twint

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import twint

# %%
c = twint.Config()

c.Search = ['covid']       # topic
c.Limit = 5000     # number of Tweets to scrape
c.Store_csv = True       # store tweets in a csv file
c.Output = "taylor_swift_tweets.csv"     # path to csv file

twint.run.Search(c)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1546429233622401026 2022-07-11 09:40:35 +0000 <dalhem_s> @UniversTennis Aïe.
# 1546429233580351488 2022-07-11 09:40:35 +0000 <sigmund_jung76> @Deadferrets The fear didn't take off, back to COVID.
# 1546429225451880448 2022-07-11 09:40:33 +0000 <Kendrickus> We werken aan aflevering 11, maar ook aan covid-aflevering 2 haha.
# 1546429219848216576 2022-07-11 09:40:31 +0000 <pera_grabljic> OTIßLI NA BUSTER COVID PARTY
# 1546429216601825281 2022-07-11 09:40:31 +0000 <testbot111222> EU recommends second COVID booster for over-60s  https://t.co/H7xzKU0eO6  https://t.co/NAO5VkTnCz
# 1546429216455024640 2022-07-11 09:40:31 +0000 <enfermeria> #ULTIMAHORA 🚨 💉🇪🇺 Las agencias sanitarias de la Unión Europea recomiendan una segunda dosis de refuerzo de vacuna anti-covid a todos los mayores de 60 años, frente al fuerte rebrote de casos. Vía #AFP  https://t.co/lKlgJXmoRu #COVID19 #vaccine  https://t.co/Sc2bJwJMXp
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
df = pd.read_csv('taylor_swift_tweets.csv')

# %%
df.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1546427681251725314  1546427681251725314  2022-07-11 09:34:25 UTC
# 1  1546427678516862981  1546174571086315521  2022-07-11 09:34:24 UTC
# 2  1546427676608585732  1546424171298754560  2022-07-11 09:34:23 UTC
# 3  1546427674964307968  1546427674964307968  2022-07-11 09:34:23 UTC
# 4  1546427673572175872  1546413389966151681  2022-07-11 09:34:23 UTC
#
#          date      time  timezone              user_id      username  \
# 0  2022-07-11  09:34:25         0  1155549785916682242        dzzsaa
# 1  2022-07-11  09:34:24         0             41840124   elaine77_04
# 2  2022-07-11  09:34:23         0  1237697793030082562     mayalab10
# 3  2022-07-11  09:34:23         0  1428236322838220802  covidhelpbot
# 4  2022-07-11  09:34:23         0  1346716432474673152  letsplayclay
#
#                        name place  \
# 0                        🇩🇿   NaN
# 1  A Little Bit of a Window   NaN
# ...

# %%
df.shape
# Out:
# (10536, 36)
